# %%
import dados_normal

# %%
K1, pontos1, labels1 = dados_normal.dados_normal_1()
dados_normal.imprimir_pontos(pontos1, labels1, 1)

K2, pontos2, labels2 = dados_normal.dados_normal_2()
dados_normal.imprimir_pontos(pontos2, labels2, 2)
