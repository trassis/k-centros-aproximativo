# %%
import experimento
import dados_sklearn

# Norma de minkowski
p = 1

K, pontos, labels = dados_sklearn.dados_circulos_1()
E = experimento.experimento(K, pontos, labels, p)
E.imprimir_experimento()
E.executar_testes()
# Out:
# Tempo para calcular matriz de dist:  2.4684479236602783
# Teste incremental feito:
# 		 Média 			 Desvio padrão
# tempo: 		 0.0016184647878011067 	 0.00041885756299757523
# raio: 		 2.423496041408116 	 0.16014020174262802
# silhueta: 	 0.3267129744953324 	 0.016072389291156657
# rand: 		 0.2826612210339191 	 0.14526762557035452
#
# Teste kmeans feito:
# 		 Média 			 Desvio padrão
# tempo: 		 0.12653098901112875 	 0.008514869372131596
# raio: 		 2.4452611811448746 	 0.15004547495817236
# silhueta: 	 0.35510472485851924 	 0.0008526832662195798
# rand: 		 0.4545710371165525 	 0.1455009706761773
#
# Teste refinamento com largura 1% feito:
# 		 Média 			 Desvio padrão
# tempo: 		 0.14240763982137045 	 0.0038827532558156795
# raio: 		 2.229698619428669 	 0.24900302627060766
# silhueta: 	 0.3222452381493159 	 0.034949763509408566
# rand: 		 0.25786837842874777 	 0.15166654395306303
#
# Teste refinamento com largura 5% feito:
# 		 Média 			 Desvio padrão
# ...
